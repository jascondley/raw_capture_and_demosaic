# %%
import os

import colour
import numpy as np

colour.plotting.colour_style()

colour.utilities.describe_environment();
# Out:
# ===============================================================================
# *                                                                             *
# *   Interpreter :                                                             *
# *       python : 3.8.2 (default, Jul 16 2020, 14:00:26)                       *
# *                [GCC 9.3.0]                                                  *
# *                                                                             *
# *   colour-science.org :                                                      *
# *       colour : 0.3.16                                                       *
# *                                                                             *
# *   Runtime :                                                                 *
# *       imageio : 2.9.0                                                       *
# *       matplotlib : 3.1.2                                                    *
# *       networkx : 2.5                                                        *
# *       numpy : 1.17.4                                                        *
# *       pandas : 1.2.1                                                        *
# *       scipy : 1.6.0                                                         *
# *       six : 1.14.0                                                          *
# *                                                                             *
# ===============================================================================

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
# This should show the moasaic'd data. Structure is there, color is wrong.
path = "/home/jas/work/bayer/test1.raw"
f = open(path, 'rb')
height = 1080
width = 1920
bin_image = np.frombuffer(f.read(), dtype=np.uint16)
bin_image = np.right_shift(bin_image, 8) # Necessary for matplotlib, values must be 0-255 aka 8-bit

print(bin_image)
bin_image.shape = (height, width)
plt.imshow(bin_image)
plt.show(block=True)
# Out:
# [ 0 25 20 ..., 21 29 16]

# %%
# convert to OpenCV and use their demoasicing
converted_image = cv2.cvtColor(bin_image, cv2.COLOR_BAYER_RG2RGB)
# converted_image = cv2.demosaicing(bin_image, cv2.COLOR_BAYER_RG2RGB)
plt.imshow(converted_image)
